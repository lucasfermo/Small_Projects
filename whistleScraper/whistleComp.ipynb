# %%
import os, sys,math,folium
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('seaborn')
from folium.plugins import HeatMap
from geopy import geocoders
from geopy.geocoders import GoogleV3
from folium.plugins import MarkerCluster
import bs4,re,requests

# %%
d=pd.read_csv('data/compOverview.csv')

d=d[d.brand.str.contains('chatr|Public|Freedom')==True]
d=d[d.price<100]
d=d[d.data<12]

color=['purple','green','orange']

plt.scatter(d.price,d.data,c=color)

# %%
# Out:
#      Unnamed: 0           brand   data    minutes  \
# 0             0  Freedom-Mobile   0.00        250
# 1             1  Freedom-Mobile   0.25  Unlimited
# 2             2  Freedom-Mobile   2.00  Unlimited
# 3             3  Freedom-Mobile  10.00       PAYG
# 4             4  Freedom-Mobile   5.00  Unlimited
# 5             5  Freedom-Mobile  10.00  Unlimited
# 6             6  Freedom-Mobile  15.00       PAYG
# 7             7  Freedom-Mobile  12.00  Unlimited
# 8             8  Freedom-Mobile  20.00       PAYG
# 9             9  Freedom-Mobile  20.00  Unlimited
# 10           10    Koodo-Mobile   0.00       PAYG
# 11           11    Koodo-Mobile   0.00         25
# 12           12    Koodo-Mobile   0.25         No
# 13           13    Koodo-Mobile   0.00        100
# 14           14    Koodo-Mobile   0.00        100
# 15           15    Koodo-Mobile   0.00        500
# 16           16    Koodo-Mobile   1.00  Unlimited
# 17           17    Koodo-Mobile   0.10        100
# 18           18    Koodo-Mobile   0.00        500
# 19           19    Koodo-Mobile   0.50        500
# 20           20    Koodo-Mobile   0.00  Unlimited
# 21           21    Koodo-Mobile   0.00  Unlimited
# 22           22    Koodo-Mobile   0.00        500
# 23           23    Koodo-Mobile   5.00  Unlimited
# 24           24    Koodo-Mobile   2.00  Unlimited
# 25           25    Koodo-Mobile   0.50  Unlimited
# 26           26    Koodo-Mobile   0.00  Unlimited
# 27           27    Koodo-Mobile   5.00  Unlimited
# 28           28    Koodo-Mobile   6.00  Unlimited
# 29           29    Koodo-Mobile   1.00  Unlimited
# ..          ...             ...    ...        ...
# 566         566   Public-Mobile   3.00  Unlimited
# 567         567   Public-Mobile   3.00  Unlimited
# 568         568   Public-Mobile   1.50  Unlimited
# 569         569   Public-Mobile   1.50  Unlimited
# 570         570   Public-Mobile  12.00  Unlimited
# 571         571   Public-Mobile   6.00  Unlimited
# 572         572   Public-Mobile   6.00  Unlimited
# 573         573   Public-Mobile   3.00  Unlimited
# 574         574   Public-Mobile   3.00  Unlimited
# 575         575   Public-Mobile   1.50  Unlimited
# 576         576   Public-Mobile  18.00  Unlimited
# 577         577   Public-Mobile  12.00  Unlimited
# 578         578   Public-Mobile   9.00  Unlimited
# 579         579   Public-Mobile   6.00  Unlimited
# 580         580   Public-Mobile   6.00  Unlimited
# 581         581   Public-Mobile   3.00  Unlimited
# 582         582   Public-Mobile  18.00  Unlimited
# 583         583   Public-Mobile  12.00  Unlimited
# 584         584   Public-Mobile   9.00  Unlimited
# 585         585   Public-Mobile   6.00  Unlimited
# 586         586   Public-Mobile  18.00  Unlimited
# 587         587   Public-Mobile  15.00  Unlimited
# 588         588   Public-Mobile   9.00  Unlimited
# 589         589   Public-Mobile  15.00  Unlimited
# 590         590   Public-Mobile  15.00  Unlimited
# 591         591  chatr-wireless   0.00         50
# 592         592  chatr-wireless   0.00  Unlimited
# 593         593  chatr-wireless   0.00  Unlimited
# 594         594  chatr-wireless   0.00  Unlimited
# 595         595  chatr-wireless   0.00  Unlimited
#
#                                                   plan  price
# 0                            $30 Data, Text &amp; Talk     20
# 1                            $40 Data, Text &amp; Talk     25
# 2                                      Big Gig 50 Plan     30
# 3                            Everywhere Canada 50 plan     40
# 4                            Everywhere Canada 60 plan     40
# 5                                      Big Gig 70 Plan     50
# 6                            Everywhere Canada 75 plan     60
# 7                                      Big Gig 90 Plan     65
# 8                           Everywhere Canada 100 plan     80
# 9                             $25 Talk &amp; Text Plan     90
# 10          $15 Prepaid Base Plan + 25 Minutes Booster     15
# 11                               $25 Prepaid Base Plan     20
# 12                              $25 - 100 Minutes Plan     25
# 13         $15 Prepaid Base Plan + 100 Minutes Booster     25
# 14                              $30 - 500 Minutes Plan     25
# 15                        $35 - Unlimited Minutes Plan     30
# 16                              $35 - 100 Minutes Plan     35
# 17                              $35 - 500 Minutes Plan     35
# 18                              $40 - 500 Minutes Plan     35
# 19                $40 - Unlimited Talk &amp; Text Plan     40
# 20                               $40 Prepaid Base Plan     40
# 21         $15 Prepaid Base Plan + 500 Minutes Booster     40
# 22                                $44 - Tab Large Plan     40
# 23                        $45 - Unlimited Minutes Plan     44
# 24                               $45 Prepaid Base Plan     45
# 25                        $45 - Unlimited Minutes Plan     45
# 26                        $48 - Unlimited Minutes Plan     45
# 27                        $49 - Unlimited Minutes Plan     48
# 28                        $50 - Unlimited Minutes Plan     49
# 29                                $54 - Tab Large Plan     50
# ..                                                 ...    ...
# 566  90-Day Unlimited Canada-Wide &amp; US Talk + T...    120
# 567   90-Day Unlimited Canada-Wide Talk + Text + 1.5GB    120
# 568   90-Day Unlimited Province-Wide Talk + Text + 6GB    120
# 569     90-Day Unlimited Canada-Wide Talk + Text + 3GB    120
# 570   90-Day Unlimited Province-Wide Talk + Text + 6GB    135
# 571  90-Day Unlimited Canada-Wide &amp; US Talk + T...    135
# 572     90-Day Unlimited Canada-Wide Talk + Text + 3GB    135
# 573  90-Day Unlimited Canada-Wide &amp; US Talk + T...    135
# 574  90-Day Unlimited Province-Wide Talk + Text + 12GB    135
# 575     90-Day Unlimited Canada-Wide Talk + Text + 6GB    135
# 576   90-Day Unlimited Province-Wide Talk + Text + 9GB    150
# 577  90-Day Unlimited Canada-Wide &amp; US Talk + T...    150
# 578     90-Day Unlimited Canada-Wide Talk + Text + 6GB    150
# 579  90-Day Unlimited Canada-Wide &amp; US Talk + T...    150
# 580    90-Day Unlimited Canada-Wide Talk + Text + 12GB    150
# 581  90-Day Unlimited Canada-Wide &amp; US Talk + T...    150
# 582     90-Day Unlimited Canada-Wide Talk + Text + 9GB    165
# 583  90-Day Unlimited Canada-Wide &amp; US Talk + T...    165
# 584  90-Day Unlimited Canada-Wide &amp; US Talk + T...    165
# 585  90-Day Unlimited Province-Wide Talk + Text + 15GB    165
# 586  90-Day Unlimited Canada-Wide &amp; US Talk + T...    180
# 587    90-Day Unlimited Canada-Wide Talk + Text + 15GB    180
# 588  90-Day Unlimited Canada-Wide &amp; US Talk + T...    180
# 589                30-Day Unlimited Province-Wide Talk    195
# 590         30-Day Unlimited Province-Wide Talk + Text    210
# 591                               Unlimited Local Talk     10
# 592                       Unlimited Province-Wide Talk     20
# 593              Unlimited Canada-Wide Talk &amp; Text     25
# 594  Unlimited Canada-Wide Talk &amp; International...     35
# 595               50 Canada-Wide Minutes &amp; 50 Text     45
#
# [596 rows x 6 columns]
